# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix,roc_curve,roc_auc_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Loading the Data

# %%
df=pd.read_csv("/content/creditcard_2023.csv",low_memory=False)

# %% [markdown]
# Understanding the data

# %%
df.shape
# Out:
# (568630, 31)

# %%
df.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
df.tail()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 568625 -0.370393  0.189694 -0.938153  ...  0.167503  0.419731  1.288249
# 568626 -0.016935 -0.147733  0.483894  ...  0.031874  0.388161 -0.154257
# 568627 -0.070958 -0.019997 -0.122048  ...  0.140788  0.536523 -0.211100
# 568628  0.580568 -0.207723  0.893527  ... -0.060381 -0.195609 -0.175488
# 568629 -0.347613 -0.340814  0.253971  ...  0.534853 -0.291514  0.157303
#
#              V24       V25       V26       V27       V28    Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486121  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %% [markdown]
# Data preprocessing

# %%
df.isna().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(df['Amount'])
plt.title('Boxplot for Transaction Amount')
plt.show()

# %%
for col in [f'V{i}' for i in range(1, 29)]:
    plt.figure(figsize=(8, 4))
    sns.boxplot(df[col])
    plt.title(f'Boxplot for Feature {col}')
    plt.show()

# %%
for col in [f'V{i}' for i in range(1, 29)]:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

# %%
lower_bound
# Out:
# -1.194081316915925

# %%
upper_bound
# Out:
# 1.3717933111899587

# %%
for col in [f'V{i}' for i in range(1, 29)]:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x='Class', y=col, data=df)
    plt.title(f'Boxplot of {col} by Class')
    plt.show()

# %%
fraud = df[df['Class'] == 1]

# %%
fraud_outliers = fraud[(fraud[[f'V{i}' for i in range(1, 29)]] > lower_bound) &
                       (fraud[[f'V{i}' for i in range(1, 29)]] < upper_bound)]
print(fraud_outliers)
# Out:
#         id        V1        V2        V3        V4        V5        V6  \
# 541    NaN -0.478427  0.142165 -0.046838  0.683350  0.067820 -0.404898
# 623    NaN -0.617111       NaN  1.150655  0.207829  0.903533 -0.171524
# 4920   NaN -0.476617  0.088942  0.326333  0.220370 -0.026730  0.432409
# 6108   NaN -0.832953 -0.024254 -0.260967  0.323532 -0.117119 -0.589167
# 6329   NaN  1.020308  0.425645 -0.554113  0.868349       NaN -0.360087
# ...     ..       ...       ...       ...       ...       ...       ...
# 568625 NaN -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626 NaN -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627 NaN -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628 NaN  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629 NaN -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
fraud_outliers_summary = fraud_outliers.describe()
non_fraud_outliers_summary = df[(df['Class'] == 0)].describe()
print("Fraudulent Transactions Outliers Summary:")
print(fraud_outliers_summary)
print("\nNon-Fraudulent Transactions Outliers Summary:")
print(non_fraud_outliers_summary)
# Out:
# Fraudulent Transactions Outliers Summary:
#         id             V1             V2             V3             V4  \
# count  0.0  223850.000000  231664.000000  222200.000000  232975.000000
# mean   NaN      -0.216802       0.228694      -0.390351       0.508789
# std    NaN       0.598250       0.490407       0.483017       0.507499
# min    NaN      -1.194072      -1.194003      -1.194079      -1.193598
# 25%    NaN      -0.682675      -0.079857      -0.741259       0.140994
# 50%    NaN      -0.313189       0.212300      -0.494601       0.512964
# 75%    NaN       0.160752       0.528310      -0.083332       0.932208
# max    NaN       1.371749       1.371779       1.371202       1.371792
#
#                   V5             V6             V7             V8  \
# count  217623.000000  215533.000000  217597.000000  245005.000000
# mean       -0.061123      -0.148016      -0.082371       0.028696
# std         0.555043       0.579733       0.523986       0.390990
# ...

# %%
lower_percentile = 0.01
upper_percentile = 0.99
for column in df.columns:
    if column not in ['id', 'Amount', 'Class']:
        lower_bound = df[column].quantile(lower_percentile)
        upper_bound = df[column].quantile(upper_percentile)
        df[column] = np.where(df[column] < lower_bound, lower_bound, df[column])
        df[column] = np.where(df[column] > upper_bound, upper_bound, df[column])

# %%
df.dtypes
# Out:
# id          int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df = df.drop(columns=['id'])

# %%
df
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -0.260648 -0.469648  2.428111 -0.083724  0.129681  0.732898  0.519014
# 1       0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2      -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3      -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4      -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454 -0.370393
# 568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148 -0.016935
# 568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098 -0.070958
# 568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148  0.580568
# 568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493 -0.347613
#
# ...

# %% [markdown]
# Scaling

# %%
x=df.drop(columns='Class')
y=df['Class']

# %%
scaler=StandardScaler()
x_scaled=scaler.fit_transform(x)

# %% [markdown]
# Splitting the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=42)

# %% [markdown]
# Exploratory Data Analysis

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Features')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df[df['Class'] == 0]['Amount'], color='blue', label='Non-Fraudulent', kde=True)
sns.histplot(df[df['Class'] == 1]['Amount'], color='red', label='Fraudulent', kde=True)
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Transaction Amounts')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6, 4))
df['Class'].value_counts().plot(kind='bar')
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %%
for col in [f'V{i}' for i in range(1, 29)]:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of Feature {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Training the model

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred =model.predict(x_test)

# %% [markdown]
# Model Evaluation

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56750
#            1       1.00      1.00      1.00     56976
#
#     accuracy                           1.00    113726
#    macro avg       1.00      1.00      1.00    113726
# weighted avg       1.00      1.00      1.00    113726

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[56736    14]
#  [    0 56976]]

# %%
roc_auc = roc_auc_score(y_test,model.predict_proba(x_test)[:, 1])
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# ROC AUC Score: 1.0000

# %%
fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:, 1])
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='b', label="ROC Curve")
plt.plot([0, 1], [0, 1], color='r', linestyle='--')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.legend(loc='lower right')
plt.show()

# %%
import joblib
joblib.dump(model,'credit_card_fraud_detection.pkl')
# Out:
# ['credit_card_fraud_detection.pkl']
